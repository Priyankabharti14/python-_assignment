# %%
'''Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of
Matplotlib.


Matplotlib:
Matplotlib is a 2D plotting library for the Python programming language. It allows you to generate high-quality
charts, graphs, and figures, making it a powerful tool for data visualization. Matplotlib provides a wide range
of customizable plots and can be used for various purposes, including exploratory data analysis, scientific 
plotting, and creating publication-quality graphics.

Uses of Matplotlib:

1.Data Visualization: Matplotlib is widely used for visualizing data to gain insights and communicate findings 
                  effectively.
2.Scientific Research: It is extensively used in scientific research to create plots for analysis and
         presentation of results.
3.Machine Learning: Matplotlib is often used in the field of machine learning to visualize training data, 
             model performance, and evaluation metrics.
4.Education: It is a valuable tool for teaching and learning data science and statistics, as it provides a
           simple interface for creating a variety of plots
    
Name five Plots using Pyplot module of Matplotlib:
    1.Line Plot
    2.Scatter Plot
    3.Bar plot
    4.Histogram
    5.Pie Chart'''
# Out:
# 'Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of\nMatplotlib.\n\n\nMatplotlib:\nMatplotlib is a 2D plotting library for the Python programming language. It allows you to generate high-quality\ncharts, graphs, and figures, making it a powerful tool for data visualization. Matplotlib provides a wide range\nof customizable plots and can be used for various purposes, including exploratory data analysis, scientific \nplotting, and creating publication-quality graphics.\n\nUses of Matplotlib:\n\n1.Data Visualization: Matplotlib is widely used for visualizing data to gain insights and communicate findings \n                  effectively.\n2.Scientific Research: It is extensively used in scientific research to create plots for analysis and\n         presentation of results.\n3.Machine Learning: Matplotlib is often used in the field of machine learning to visualize training data, \n             model performance, and evaluation metrics.\n
# ...

# %%
'''Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
plot a scatter plot.
import numpy as np
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))
Note: Also add title, xlabel, and ylabel to the plot.'''

import matplotlib.pyplot as plt
import numpy as np
np.random.seed(3)
x = 3 + np.random.normal(0 ,2, 50)
y = 3 + np.random.normal(0, 2, len(x))
plt.scatter(x,y)
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("scatter plot")
plt.show()

# %%
'''Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.
Use the following data:
import numpy as np
For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])
For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])'''


'''The subplot() function in Matplotlib is used to create a grid of subplots within a single figure. 
It allows you to organize multiple plots in a single figure, making it convenient for comparing and 
analyzing different datasets.'''

import numpy as np
import matplotlib.pyplot as plt

# Data for four lines
x = np.array([0, 1, 2, 3, 4, 5])

# Line 1
y1 = np.array([0, 100, 200, 300, 400, 500])

# Line 2
y2 = np.array([50, 20, 40, 20, 60, 70])

# Line 3
y3 = np.array([10, 20, 30, 40, 50, 60])

# Line 4
y4 = np.array([200, 350, 250, 550, 450, 150])

# Create subplots
plt.subplot(2, 2, 1)
plt.plot(x, y1)
plt.title('Line 1')

plt.subplot(2, 2, 2)
plt.plot(x, y2)
plt.title('Line 2')

plt.subplot(2, 2, 3)
plt.plot(x, y3)
plt.title('Line 3')

plt.subplot(2, 2, 4)
plt.plot(x, y4)
plt.title('Line 4')

plt.tight_layout()
plt.show()

# %%
'''Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.
import numpy as np
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])'''

import matplotlib.pyplot as plt
import numpy as np
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])
plt.bar(company,profit)
plt.show()

# %%
'''Q5: What is a box plot? Why is it used? Using the following data plot a box plot.
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)'''


'''Box Plot:
A box plot, also known as a box-and-whisker plot, is a graphical representation of the distribution of a dataset.
It displays the summary of a set of data values, showing the minimum, first quartile (Q1), median, third 
quartile (Q3), and maximum. The box represents the interquartile range (IQR) between Q1 and Q3, while the
whiskers extend from the box to the minimum and maximum values within a certain range. Outliers may also be
displayed as individual points.'''

import matplotlib.pyplot as plt
import numpy as py
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)
plt.boxplot([box1,box2],labels=['box1','box2'])
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("box plot")
plt.show()
